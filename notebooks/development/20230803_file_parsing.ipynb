# %% [markdown]
# # File Parsing

# %%
from pathlib import Path

# %%
for file in Path('../data/mp3s/').glob('*.mp3'):
    print(file)

# %%
path = Path('../data/mp3s/')
for p in path.rglob("*.mp3"):
     print(p.name)
# Out:
# Weezer - Take on Me.mp3
# Manwolves - Shkleepy.mp3
# Dirty Audio, BL3R, Young Buck - Bandana (feat. Young Buck).mp3
# Phoenix - Chloroform.mp3
# majiko - Mawaranai Toe Shoes.mp3
# Good Scott - moonwalking.mp3
# Jo Dee Messina - Because You Love Me.mp3
# Mac Ayres - Easy.mp3
# Maldita Vecindad Y Los Hijos Del 5to. Patio - Don Palabras.mp3
# rei brown - Landing On Mars.mp3
# Wiz Khalifa - Stayin out All Night.mp3
# Gojira - L'enfant sauvage.mp3
# Tempo - El Bruto.mp3
# Kai Straw - Slaughterhouse.mp3
# Brett Eldredge - Somethin' I'm Good At.mp3
# Claude Debussy, Fazıl Say - Debussy# Preludes, Book 1, L. 117# VIII. La fille aux cheveux de lin.mp3
# Mili - Fushicho.mp3
# AC Slater, Sinden, Young Lyxx - Ring the Alarm.mp3
# Rancid - All American Neighborhood.mp3
# Lil Xan - Betrayed.mp3
# MC YOGI, Jai Uttal - Ganesh Is Fresh (feat. Jai Uttal).mp3
# ...
